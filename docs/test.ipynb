# %%
from illumination import *

# %%
create_directory_of_fits()

# %%
s = FITS_Sequence('someplace/cam1/*')

# %%
illustration = CCDIllustration(data=s)
illustration.plot()
filename = 'test-nimation.mp4'
illustration.animate(filename)
